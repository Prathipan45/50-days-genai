# %%
# %pip install google-genai python-dotenv

# %%
from google import genai
from google.genai import types
import os
from dotenv import load_dotenv

load_dotenv(dotenv_path='./.env_example')

API_KEY = os.environ["GEMINI_API_KEY"]

client = genai.Client(api_key=API_KEY)
response = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Hi name is prathipan. I love to code in python. Write a short bio about me.',
)
print(os.environ)
print(response.text)
# Out:
# environ({'ALLUSERSPROFILE': 'C:\\ProgramData', 'AMDRMSDKPATH': 'C:\\Program Files\\AMD\\RyzenMasterSDK\\', 'APPDATA': 'C:\\Users\\prath\\AppData\\Roaming', 'CHOCOLATEYINSTALL': 'C:\\ProgramData\\chocolatey', 'CHOCOLATEYLASTPATHUPDATE': '134150899696564576', 'CHROME_CRASHPAD_PIPE_NAME': '\\\\.\\pipe\\crashpad_12068_VZWSRBCGMNDMQZRD', 'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files', 'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files', 'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files', 'COMPUTERNAME': 'LAPTOP-OBCU9P1J', 'COMSPEC': 'C:\\WINDOWS\\system32\\cmd.exe', 'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData', 'EFC_23800_1592913036': '1', 'ELECTRON_RUN_AS_NODE': '1', 'HOMEDRIVE': 'C:', 'HOMEPATH': '\\Users\\prath', 'INTELLIJ IDEA COMMUNITY EDITION': 'C:\\Program Files\\JetBrains\\IntelliJ IDEA Community Edition 2025.2.4\\bin', 'JAVA_HOME': 'C:\\Program Files\\Amazon Corretto\\jdk1.8.0_472', 'JPY_INTERRUPT_EVENT': '3464', 'LOCALAPPDATA': 'C:\\Users\\prath\\AppData\\Local', 'LOGONSERVER': '\\\\LAPTOP-OBCU9P1J', 'NUMBER_OF_PROCESSORS': '12', 'ONEDRIVE': 'C:\\Users\\prath\\OneDrive', 'ONEDRIVECONSUMER': 'C:\\Users\\prath\\OneDrive', 'ONLINESERVICES': 'Online Services', 'OS': 'Windows_NT', 'PATH': 'e:\\50 days challenge\\myenv\\Scripts;E:\\50 days challenge\\myenv\\Scripts;C:\\Users\\prath\\AppData\\Local\\Programs\\Microsoft VS Code;C:\\Program Files\\Amazon Corretto\\jdk1.8.0_472\\bin;C:\\Program Files\\Common Files\\Oracle\\Java\\javapath;C:\\windows\\system32;C:\\windows;C:\\windows\\System32\\Wbem;C:\\windows\\System32\\WindowsPowerShell\\v1.0\\;C:\\windows\\System32\\OpenSSH\\;C:\\WINDOWS\\system32;C:\\WINDOWS;C:\\WINDOWS\\System32\\Wbem;C:\\WINDOWS\\System32\\WindowsPowerShell\\v1.0\\;C:\\WINDOWS\\System32\\OpenSSH\\;C:\\Program Files\\Git\\cmd;C:\\ProgramData\\chocolatey\\bin;C:\\Program Files\\nodejs\\;C:\\Users\\prath\\AppData\\Local\\Programs\\Python\\Python313\\Scripts\\;C:\\Users\\prath\\AppData\\Local\\Programs\\Python\\Python313\\;C:\\Users\\prath\\AppData\\Local\\Programs\\Python\\Python312\\Scripts\\;C:\\Users\\prath\\AppData\\Local\\Programs\\Python\\Python312\\;C:\\Users\\prath\\AppData\\Local\\Programs\\Python\\Launcher\\;C:\\Users\\prath\\AppData\\Local\\Microsoft\\WindowsApps;C:\\Users\\prath\\AppData\\Local\\Programs\\Microsoft VS Code\\bin;C:\\Users\\prath\\AppData\\Local\\Programs\\Ollama;C:\\Program Files\\JetBrains\\IntelliJ IDEA Community Edition 2025.2.4\\bin;C:\\Users\\prath\\AppData\\Roaming\\npm;C:\\Users\\prath\\.local\\bin;', 'PATHEXT': '.COM;.EXE;.BAT;.CMD;.VBS;.VBE;.JS;.JSE;.WSF;.WSH;.MSC', 'PLATFORMCODE': 'M7', 'PROCESSOR_ARCHITECTURE': 'AMD64', 'PROCESSOR_IDENTIFIER': 'AMD64 Family 25 Model 80 Stepping 0, AuthenticAMD', 'PROCESSOR_LEVEL': '25', 'PROCESSOR_REVISION': '5000', 'PROGRAMDATA': 'C:\\ProgramData', 'PROGRAMFILES': 'C:\\Program Files', 'PROGRAMFILES(X86)': 'C:\\Program Files (x86)', 'PROGRAMW6432': 'C:\\Program Files', 'PROMPT': '(myenv) $P$G', 'PSMODULEPATH': 'C:\\Program Files\\WindowsPowerShell\\Modules;C:\\WINDOWS\\system32\\WindowsPowerShell\\v1.0\\Modules', 'PUBLIC': 'C:\\Users\\Public', 'PYDEVD_IPYTHON_COMPATIBLE_DEBUGGING': '1', 'PYTHONIOENCODING': 'utf-8', 'PYTHONUNBUFFERED': '1', 'PYTHON_FROZEN_MODULES': 'on', 'REGIONCODE': 'APJ', 'SESSIONNAME': 'Console', 'SYSTEMDRIVE': 'C:', 'SYSTEMROOT': 'C:\\WINDOWS', 'TEMP': 'C:\\Users\\prath\\AppData\\Local\\Temp', 'TMP': 'C:\\Users\\prath\\AppData\\Local\\Temp', 'USERDOMAIN': 'LAPTOP-OBCU9P1J', 'USERDOMAIN_ROAMINGPROFILE': 'LAPTOP-OBCU9P1J', 'USERNAME': 'prath', 'USERPROFILE': 'C:\\Users\\prath', 'VBOX_HWVIRTEX_IGNORE_SVM_IN_USE': '1', 'VBOX_MSI_INSTALL_PATH': 'C:\\Program Files\\Oracle\\VirtualBox\\', 'VIRTUAL_ENV': 'E:\\50 days challenge\\myenv', 'VIRTUAL_ENV_PROMPT': 'myenv', 'VSCODE_CODE_CACHE_PATH': 'C:\\Users\\prath\\AppData\\Roaming\\Code\\CachedData\\8b640eef5a6c6089c029249d48efa5c99adf7d51', 'VSCODE_CRASH_REPORTER_PROCESS_TYPE': 'extensionHost', 'VSCODE_CWD': 'C:\\Users\\prath\\AppData\\Lo ...
# Here are a few options for a short bio about you, Prathipan, emphasizing your love for coding in Python:
#
# **Option 1 (Concise & Enthusiastic):**
# > Prathipan is a dedicated Python enthusiast who loves diving into code, crafting solutions, and bringing ideas to life with Python.
#
# **Option 2 (Slightly More Evocative):**
# > Meet Prathipan, whose passion truly ignites when he's coding in Python. He loves the challenge of turning concepts into elegant, functional code and seeing his projects come to life.
#
# **Option 3 (Professional & Straightforward):**
# > Prathipan is a passionate Python coder with a strong interest in developing innovative solutions. He thrives on exploring Python's versatility and applying his skills to various projects.
#
# **Option 4 (Short & Sweet):**
# > Prathipan is a passionate Pythonista who loves to code and build. Python is his playground for turning ideas into reality.
#
# Choose the one that best fits your style, or let me know if you'd like any adjustments!
