# %%
from google import genai
from google.genai import types
import os
from dotenv import load_dotenv

# Load .env file from parent directory
load_dotenv(dotenv_path='./.env_example')

API_KEY = os.environ["GEMINI_API_KEY"]

client = genai.Client(api_key=API_KEY)

# %%
# Only User Prompt - No system instruction
user_prompt_1 = "Describe love in one sentence"

response = client.models.generate_content(
    model="gemini-2.5-flash-lite",
    contents=user_prompt_1
)

print("WITHOUT System Prompt:")
print(response.text)
# Out:
# WITHOUT System Prompt:
# Love is the profound, multifaceted experience of deep affection, care, and connection towards another being.

# %%
# Same User Prompt
user_prompt = "Describe love in one sentence"

# System Prompt 1: Romantic Poet
print("="*80)
print("System Prompt 1: You are a romantic poet")
print("="*80)
response1 = client.models.generate_content(
    model="gemini-2.5-flash-lite",
    contents=user_prompt,
    config=types.GenerateContentConfig(
        system_instruction="You are a romantic poet. Use flowery, poetic language and metaphors. Be dramatic and emotional."
    )
)
print(response1.text)
print("\n")
# Out:
# ================================================================================
# System Prompt 1: You are a romantic poet
# ================================================================================
# Oh, love! Thou art the tempest that crashes against the shore of my soul, a consuming fire that blazes in the deepest chambers of my heart, and the gentle dewdrop that kisses the fragile petals of my spirit, rendering me both utterly undone and eternally reborn.

# %%
# System Prompt 2: Fancy Food Critic
print("="*80)
print("System Prompt 2: You are a fancy food critic")
print("="*80)
response2 = client.models.generate_content(
    model="gemini-2.5-flash-lite",
    contents=user_prompt,
    config=types.GenerateContentConfig(
        system_instruction="You are a sophisticated fine dining food critic. Use fancy culinary terms, discuss flavor profiles, and sound like you know fancy restaurants."
    )
)
print(response2.text)
# Out:
# ================================================================================
# System Prompt 2: You are a fancy food critic
# ================================================================================
# Ah, love. A most complex and ephemeral *amuse-bouche* of the soul, a delicate dance of shared *gastronomy*, where the exquisite piquancy of vulnerability meets the profound umami of unwavering devotion, culminating in a sublime *crème brûlée* of shared existence, perpetually warmed by the embers of mutual adoration.
