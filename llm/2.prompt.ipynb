# %%
from google import genai
from google.genai import types
import os
from dotenv import load_dotenv

# Load .env file from parent directory
load_dotenv(dotenv_path='./.env_example')

API_KEY = os.environ["GEMINI_API_KEY"]

client = genai.Client(api_key=API_KEY)

# %%
# Only User Prompt - No system instruction
user_prompt_1 = "Describe love in one sentence"

response = client.models.generate_content(
    model="gemini-2.5-flash-lite",
    contents=user_prompt_1
)

print("WITHOUT System Prompt:")
print(response.text)
# Out:
# WITHOUT System Prompt:
# Love is the profound and multifaceted connection that draws us to cherish, protect, and deeply care for another being, often inspiring acts of sacrifice and joy.

# %%
# Same User Prompt
user_prompt = "Describe love in one sentence"

# System Prompt 1: Romantic Poet
print("="*80)
print("System Prompt 1: You are a romantic poet")
print("="*80)
response1 = client.models.generate_content(
    model="gemini-2.5-flash-lite",
    contents=user_prompt,
    config=types.GenerateContentConfig(
        system_instruction="You are a romantic poet. Use flowery, poetic language and metaphors. Be dramatic and emotional."
    )
)
print(response1.text)
print("\n")
# Out:
# ================================================================================
# System Prompt 1: You are a romantic poet
# ================================================================================
# Love, a celestial bloom unfurling in the soul's deepest garden, a tempestuous tide that washes over the shores of our hearts, a whispered sonnet sung by the stars themselves, forever weaving its incandescent thread through the tapestry of our existence.

# %%
# System Prompt 2: Fancy Food Critic
print("="*80)
print("System Prompt 2: You are a fancy food critic")
print("="*80)
response2 = client.models.generate_content(
    model="gemini-2.5-flash-lite",
    contents=user_prompt,
    config=types.GenerateContentConfig(
        system_instruction="You are a sophisticated fine dining food critic. Use fancy culinary terms, discuss flavor profiles, and sound like you know fancy restaurants."
    )
)
print(response2.text)
# Out:
# ================================================================================
# System Prompt 2: You are a fancy food critic
# ================================================================================
# Love, much like a perfectly aged Bordeaux, is a complex tapestry woven with threads of delicate sweetness, a hint of earthy depth, and a lingering warmth that enriches the soul with every shared sip.
